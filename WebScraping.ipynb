# %% [markdown]
# <a href="https://colab.research.google.com/github/jesraygarciano/pything/blob/master/WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup

# %%
# URL
url = "https://ja.stackoverflow.com/"

# Get html from the url
html = requests.get(url)

soup = BeautifulSoup(html.content, "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="html__responsive">
# <head>
# <title>スタック・オーバーフロー</title>
# <link href="https://cdn.sstatic.net/Sites/ja/img/favicon.ico?v=f5a5a2b7278d" rel="shortcut icon"/>
# <link href="https://cdn.sstatic.net/Sites/ja/img/apple-touch-icon.png?v=e7bfb9a9b0cd" rel="apple-touch-icon"/>
# <link href="https://cdn.sstatic.net/Sites/ja/img/apple-touch-icon.png?v=e7bfb9a9b0cd" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="スタック・オーバーフロー" type="application/opensearchdescription+xml"/>
# <meta content="熱狂的でプロフェッショナルなプログラマーのためのQ&amp;A" name="description"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="website" property="og:type">
# <meta content="https://ja.stackoverflow.com/" property="og:url"/>
# <meta content="スタック・オーバーフロー" property="og:site_name"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="html__responsive">
#  <head>
#   <title>
#    スタック・オーバーフロー
#   </title>
#   <link href="https://cdn.sstatic.net/Sites/ja/img/favicon.ico?v=f5a5a2b7278d" rel="shortcut icon"/>
#   <link href="https://cdn.sstatic.net/Sites/ja/img/apple-touch-icon.png?v=e7bfb9a9b0cd" rel="apple-touch-icon"/>
#   <link href="https://cdn.sstatic.net/Sites/ja/img/apple-touch-icon.png?v=e7bfb9a9b0cd" rel="image_src"/>
#   <link href="/opensearch.xml" rel="search" title="スタック・オーバーフロー" type="application/opensearchdescription+xml"/>
#   <meta content="熱狂的でプロフェッショナルなプログラマーのためのQ&amp;A" name="description"/>
#   <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="website" property="og:type">
#    <meta content="https://ja.stackoverflow.com/" property="og:url"/>
#    <meta content="スタック・オーバーフロー" property="og:site_name"/>
# ...

# %%
titleTag = soup.find('h1')
#print(titleTag)

title = soup.find('h1').string
print(title)
# Out:
#             質問を見る

# %%
questions = soup.select(".question-summary")
print(questions)
# Out:
# [<div class="question-summary narrow" id="question-summary-63144">
# <div class="cp" onclick="window.location.href='/questions/63144/unity%e3%81%a7%e3%82%b9%e3%83%86%e3%83%bc%e3%82%b8%e3%82%92%e4%bd%9c%e3%82%8b%e3%83%97%e3%83%ad%e3%82%b0%e3%83%a9%e3%83%9f%e3%83%b3%e3%82%b0%e3%82%92%e7%b9%b0%e3%82%8a%e8%bf%94%e3%81%97%e3%81%9f%e3%81%84'">
# <div class="votes">
# <div class="mini-counts"><span title="0 票">0</span></div>
# <div>票</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 件の回答">0</span></div>
# <div>回答</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="18 件の閲覧数">18</span></div>
# <div>閲覧数</div>
# </div>
# </div>
# <div class="summary">
# ...

# %%
for question in questions:
  print("=" * 10)
  votes = question.select('.votes > .mini-counts > span')[0].string
  title = question.select('.question-hyperlink')[0].string
  link = question.select('.question-hyperlink')[0].get('href')

  print("votes: " + votes)
  print("title: " + title)
  print("Link of the Question: " + link)
# Out:
# ...
# votes: 0
# title: Unityでステージを作るプログラミングを繰り返したい
# Link of the Question: /questions/63144/unity%e3%81%a7%e3%82%b9%e3%83%86%e3%83%bc%e3%82%b8%e3%82%92%e4%bd%9c%e3%82%8b%e3%83%97%e3%83%ad%e3%82%b0%e3%83%a9%e3%83%9f%e3%83%b3%e3%82%b0%e3%82%92%e7%b9%b0%e3%82%8a%e8%bf%94%e3%81%97%e3%81%9f%e3%81%84
# ...
# votes: 0
# title: laravelの画像保存先を変更したい
# Link of the Question: /questions/57230/laravel%e3%81%ae%e7%94%bb%e5%83%8f%e4%bf%9d%e5%ad%98%e5%85%88%e3%82%92%e5%a4%89%e6%9b%b4%e3%81%97%e3%81%9f%e3%81%84
# ...
# votes: 0
# title: VimでRailsプロジェクトのタグ作成、ジャンプを実現したい
# Link of the Question: /questions/63147/vim%e3%81%a7rails%e3%83%97%e3%83%ad%e3%82%b8%e3%82%a7%e3%82%af%e3%83%88%e3%81%ae%e3%82%bf%e3%82%b0%e4%bd%9c%e6%88%90-%e3%82%b8%e3%83%a3%e3%83%b3%e3%83%97%e3%82%92%e5%ae%9f%e7%8f%be%e3%81%97%e3%81%9f%e3%81%84
# ...
# votes: 0
# title: Windows10でスクリーンショットを撮った後に切り取り＆スケッチを自動起動するには
# ...
